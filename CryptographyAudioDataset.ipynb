# %%
import shutil
import os

# %%
main = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset"

# %%
one = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase"
two = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\differentPhrase"

# %%
directories = [one,two]
dir_num = random.randint(0,len(directories)-1)
sub = directories[dir_num]
files = os.listdir(sub)
rand_dir = random.randint(0,len(files)-1)
fol_path = files[rand_dir]
new_path = os.path.join(sub,fol_path)
fol_files = os.listdir(new_path)
for i in range(len(fol_files)):
    final_path = os.path.join(new_path,fol_files[i])
    print(final_path)
# Out:
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-1.flac
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-10.flac
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-2.flac
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-3.flac
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-4.flac
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\64\64-5.flac
# ...

# %%
dirs = os.listdir(main)
for i in range(len(dirs)):
    copy_to_path = os.path.join(main,dirs[i])
    print(copy_to_path)
    directories = [one,two]
    dir_num = random.randint(0,len(directories)-1)
    sub = directories[dir_num]
    files = os.listdir(sub)
    rand_dir = random.randint(0,len(files)-1)
    fol_path = files[rand_dir]
    new_path = os.path.join(sub,fol_path)
    fol_files = os.listdir(new_path)
    print(new_path)
    for i in range(len(fol_files)):
        final_path = os.path.join(new_path,fol_files[i])
        shutil.copy2(final_path, copy_to_path)
# Out:
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset\Aaron_Eckhart
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\17
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset\Aaron_Guiel
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\45
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset\Aaron_Patterson
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\samePhrase\65
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset\Aaron_Peirsol
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\111
# C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\AudioDataset\Aaron_Pena
# ...

# %%
identity = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\lfw-funneled\lfw_funneled"
signature = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\SignatureDataset"
copy_signature = r"C:\Users\dharu\OneDrive\Desktop\6th Semester\Cryptography\CEDAR\CEDAR"

# %%
file_names = os.listdir(identity)
file_names
# Out:
# ['Aaron_Eckhart',
#  'Aaron_Guiel',
#  'Aaron_Patterson',
#  'Aaron_Peirsol',
#  'Aaron_Pena',
#  'Aaron_Sorkin',
#  'Aaron_Tippin',
#  'Abbas_Kiarostami',
#  'Abba_Eban',
#  'Abdel_Aziz_Al-Hakim',
#  'Abdel_Madi_Shabneh',
#  'Abdel_Nasser_Assidi',
#  'Abdoulaye_Wade',
#  'Abdulaziz_Kamilov',
#  'Abdullah',
#  'Abdullah_Ahmad_Badawi',
#  'Abdullah_al-Attiyah',
#  'Abdullah_Gul',
#  'Abdullah_Nasseef',
#  'Abdullatif_Sener',
#  'Abdul_Majeed_Shobokshi',
#  'Abdul_Rahman',
#  'Abel_Aguilar',
#  'Abel_Pacheco',
#  'Abid_Hamid_Mahmud_Al-Tikriti',
#  'Abner_Martinez',
#  'Abraham_Foxman',
#  'Aby_Har-Even',
#  'Adam_Ant',
#  'Adam_Freier',
#  'Adam_Herbert',
#  'Adam_Kennedy',
#  'Adam_Mair',
#  'Adam_Rich',
#  'Adam_Sandler',
#  'Adam_Scott',
#  'Adelina_Avila',
#  'Adel_Al-Jubeir',
#  'Adisai_Bodharamik',
#  'Adolfo_Aguilar_Zinser',
#  'Adolfo_Rodriguez_Saa',
#  'Adoor_Gopalakarishnan',
#  'Adriana_Lima',
#  'Adriana_Perez_Navarro',
#  'Adrianna_Zuzic',
#  'Adrian_Annus',
# ...

# %%
for i in file_names:
    sign_part = os.path.join(signature,i)
    os.mkdir(sign_part)

# %%
import random
total = os.listdir(signature)
file_signs = os.listdir(copy_signature)
folder_num = random.randint(0,len(file_signs)-1)
for i in total:
    file_signs = os.listdir(copy_signature)
    folder_num = random.randint(0,len(file_signs)-1)
    destination = os.path.join(signature,i)
    source = os.path.join(copy_signature,file_signs[folder_num])
    signs = os.listdir(source)
    for j in signs:
        fle = os.path.join(source,j)
        dst_file = os.path.join(destination,j)
        shutil.copyfile(fle, dst_file)
